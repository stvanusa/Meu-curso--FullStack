# %%
#print simples

print('Olá mundo')
print('Qual o seu nome')
print('Qual sua idade')
print('Qual seu curso?')

# %%
#Variáveis
int=123           #tipo:inteiro
str='vanusa'      #tipo:texto
float=10.5        #tipo:real
bool=True         #tipo:verdadeiro/falso

# %%
#Prinnt formatado
nome='vanusa'
idade=20
print(f'Olá {nome}')
print(f'Olá {nome}, você tem {idade} anos')
# Out:
# Olá vanusa
# Olá vanusa, você tem 20 anos

# %%
#Conversao de variaveis
x=str(123)
print(type(x)) # inserindo numero porem convertido para texto

# aqui define a variavel y
y=int('123') #inserindo texto porem convertido para numero inteiro
print(type(y))

z= float('12.3') #inserindo texto porem convertido para numero racionais(fracionado)
print(type(z))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
